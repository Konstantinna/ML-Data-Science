# %% [markdown]
#  # Visualizing Data with Python
#
#  _Source: Coursework & Lab Recap for **[IBM Data Science Specialization | Course: Python for Data Visualization](https://www.coursera.org/learn/python-for-data-visualization)**_

# %% [markdown]
# ## Intro to Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
#Drawing a basic plot 
plt.plot(10,10,'o')
plt.show()

# %% [markdown]
# ### Magic functions

# %% [markdown]
# To generate plots within the browswer we can use a **magic function** with **%**
#
# However with the **%matplotlib inline** backend method, once a figure is rendered we cannot change it (add titles, etc)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# If we use **%matplotlib notebook**, the backend checks if a figure already exists in the notebook. If there isn't an active one, a new one is generated. With this backend we can also easily add a title evenwhen the figure is generated

# %%
# %matplotlib notebook

# %% [markdown]
# ### Built-in Pandas

# %% [markdown]
# * Pandas have a built-in implementation. You just have to call the plot function to a panda series/df
#
# * pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python
#
# * The course heavily relies on pandas for data wrangling, analysis, and visualization

# %%
#namedf.plot(kind="line") #Trendline
#namedf.plot(kind="hist") #Histogram

# %% [markdown]
# ## LAB | IM CA The Great White North

# %%
import numpy as np #for sci computing
import pandas as pd #primary data structure library
from __future__ import print_function #python2 compatibility

df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx', sheet_name="Canada by Citizenship", skiprows=range(20), skip_footer=2)
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...   2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...   2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...   1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...   3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...      0     0     1
# 4  Southern Europe  901   Developed regions     0  ...      0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %% [markdown]
# ### Data Understanding
#
# For summary stats,info,shape and list of column and indicies, run the following:

# %%
print ("Describe\n\n",df_can.describe())
#print ("Info \n \n", df_can.info)
print ("Shape \n \n",df_can.shape)
print ("Type \n \n",(type (df_can)))
print ("Columns \n \n", df_can.columns.values)
print ("Index \n \n",df_can.index.values)
# Out:
# Describe
#
#               AREA          REG         DEV          1980          1981  \
# count  195.000000   195.000000  195.000000    195.000000    195.000000
# mean   912.764103  1249.015385  901.753846    508.394872    566.989744
# std     13.082835  1185.526885    0.431878   1949.588546   2152.643752
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.000000     10.000000
# 75%    922.000000   925.500000  902.000000    251.500000    295.500000
# max    935.000000  5501.000000  902.000000  22045.000000  24796.000000
#
#                1982          1983          1984         1985         1986  \
# count    195.000000    195.000000    195.000000   195.000000   195.000000
# mean     534.723077    387.435897    376.497436   358.861538   441.271795
# std     1866.997511   1204.333597   1198.246371  1079.309600  1225.576630
# ...

# %% [markdown]
# ### Data Prep
#
# * Add country name ('OdName') as **Index**
#
# * Add a column summarizing the **Total** number of migrants
#
# * Typically the default type of index and columns is NOT a list, so they have to be converted using **tolist()**

# %%
#df_can.set_index('OdName', inplace = True) #Using Country names as an Index, once it is done, the line cannot be executed anymore
df_can['Total'] = df_can.sum(axis=1)

df_can.columns.tolist()
#df_can.index.tolist()
df_can
# Out:
#            Type    Coverage  \
# 0    Immigrants  Foreigners
# 1    Immigrants  Foreigners
# 2    Immigrants  Foreigners
# 3    Immigrants  Foreigners
# 4    Immigrants  Foreigners
# 5    Immigrants  Foreigners
# 6    Immigrants  Foreigners
# 7    Immigrants  Foreigners
# 8    Immigrants  Foreigners
# 9    Immigrants  Foreigners
# 10   Immigrants  Foreigners
# 11   Immigrants  Foreigners
# 12   Immigrants  Foreigners
# 13   Immigrants  Foreigners
# 14   Immigrants  Foreigners
# 15   Immigrants  Foreigners
# 16   Immigrants  Foreigners
# 17   Immigrants  Foreigners
# 18   Immigrants  Foreigners
# 19   Immigrants  Foreigners
# 20   Immigrants  Foreigners
# 21   Immigrants  Foreigners
# 22   Immigrants  Foreigners
# 23   Immigrants  Foreigners
# 24   Immigrants  Foreigners
# 25   Immigrants  Foreigners
# 26   Immigrants  Foreigners
# 27   Immigrants  Foreigners
# 28   Immigrants  Foreigners
# 29   Immigrants  Foreigners
# ..          ...         ...
# 165  Immigrants  Foreigners
# ...

# %% [markdown]
# * Clean unnencessary columns with **drop()**- 0 axis for rows, 1 axis for columns
# * Rename **columns**
# * Check for **null objects**

# %%
# in pandas axis=0 represents rows (default) and axis=1 represents columns.
#df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)  > Cleaned on 1st iteration, command no longer needed on 2nd

df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.index
df_can
# Out:
#            Type    Coverage  \
# 0    Immigrants  Foreigners
# 1    Immigrants  Foreigners
# 2    Immigrants  Foreigners
# 3    Immigrants  Foreigners
# 4    Immigrants  Foreigners
# 5    Immigrants  Foreigners
# 6    Immigrants  Foreigners
# 7    Immigrants  Foreigners
# 8    Immigrants  Foreigners
# 9    Immigrants  Foreigners
# 10   Immigrants  Foreigners
# 11   Immigrants  Foreigners
# 12   Immigrants  Foreigners
# 13   Immigrants  Foreigners
# 14   Immigrants  Foreigners
# 15   Immigrants  Foreigners
# 16   Immigrants  Foreigners
# 17   Immigrants  Foreigners
# 18   Immigrants  Foreigners
# 19   Immigrants  Foreigners
# 20   Immigrants  Foreigners
# 21   Immigrants  Foreigners
# 22   Immigrants  Foreigners
# 23   Immigrants  Foreigners
# 24   Immigrants  Foreigners
# 25   Immigrants  Foreigners
# 26   Immigrants  Foreigners
# 27   Immigrants  Foreigners
# 28   Immigrants  Foreigners
# 29   Immigrants  Foreigners
# ..          ...         ...
# 165  Immigrants  Foreigners
# ...

# %% [markdown]
# ### Indexing & Selection (Slicing)
#
# Select Column¶
# There are two ways to filter on a column name:
#
# Method 1: Quick and easy, but only works if the column name does NOT have spaces or special characters.
#
#     df.column_name
#         (returns series)
# Method 2: More robust, and can filter on multiple columns.
#
#     df['column']
#         (returns series)
#     df[['column 1', 'column 2']]
#         (returns dataframe)

# %%
df_can.Country
# Out:
# 0                                            Afghanistan
# 1                                                Albania
# 2                                                Algeria
# 3                                         American Samoa
# 4                                                Andorra
# 5                                                 Angola
# 6                                    Antigua and Barbuda
# 7                                              Argentina
# 8                                                Armenia
# 9                                              Australia
# 10                                               Austria
# 11                                            Azerbaijan
# 12                                               Bahamas
# 13                                               Bahrain
# 14                                            Bangladesh
# 15                                              Barbados
# ...

# %% [markdown]
# #### Filtering by Country and data for a range of years, e.g 1980- 1985

# %%
df_can[['Country', 1980, 1981, 1982, 1983, 1984, 1985]] # returns a dataframe
# notice that 'Country' is string, and the years are integers. 
# for the sake of consistency, we will convert all column names to string later on.
# Out:
#                                                Country   1980   1981   1982  \
# 0                                          Afghanistan     16     39     39
# 1                                              Albania      1      0      0
# 2                                              Algeria     80     67     71
# 3                                       American Samoa      0      1      0
# 4                                              Andorra      0      0      0
# 5                                               Angola      1      3      6
# 6                                  Antigua and Barbuda      0      0      0
# 7                                            Argentina    368    426    626
# 8                                              Armenia      0      0      0
# 9                                            Australia    702    639    484
# 10                                             Austria    234    238    201
# ...

# %% [markdown]
# ### Selecting Row
#
# There are main 3 ways to select rows:
#
#     df.loc[label]
#         #filters by the labels of the index/column
#     df.iloc[index]
#         #filters by the positions of the index/column
#
# But to know which row to access we need to have them indexed with **set_index()**.

# %%
#print(df_can.loc['Bulgaria'])

# %%
#df_can.set_index('Country', inplace=True)
# tip: The opposite of set is reset. So to reset the index, we can use df_can.reset_index()

# %% [markdown]
# Column names that are integers (such as the years) might introduce some confusion. For example, when we are referencing the year 2013, one might confuse that when the 2013th positional index.
#
# To avoid this ambuigity, let's convert the column names into strings: '1980' to '2013'.

# %%
df_can.columns = list(map(str, df_can.columns))
# [print (type(x)) for x in df_can.columns.values] #<-- uncomment to check type of column headers

years = list(map(str, range(1980, 2014)))
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %% [markdown]
# ### Criteria-based filtering
#
# * 1. create the condition boolean series
# * 2. pass this condition into the dataFrame
# * 3. pass mutliple criteria in the same line

# %%
#condition = df_can['Continent'] == 'Asia'
#print(condition)

print('data dimensions:', df_can.shape)
print(df_can.columns)
df_can.head(2)
# Out:
# data dimensions: (195, 44)
# Index(['Type', 'Coverage', 'Country', 'AREA', 'Continent', 'REG', 'Region',
#        'DEV', 'DevName', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', 'Total'],
#       dtype='object')
#          Type    Coverage      Country  AREA Continent   REG           Region  \
# 0  Immigrants  Foreigners  Afghanistan   935      Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908    Europe   925  Southern Europe
#
#    DEV             DevName  1980  ...    2005  2006  2007  2008  2009  2010  \
# 0  902  Developing regions    16  ...    3436  3009  2652  2111  1746  1758
# 1  901   Developed regions     1  ...    1223   856   702   560   716   561
#
#    2011  2012  2013  Total
# ...

# %% [markdown]
# # Matplotlib
#
# Matplotlib is a Python 2D plotting library which produces **publication quality figures in a variety of hardcopy formats and interactive environments across platforms**.
#
# Matplotlib can be used in:
# - Python scripts,
# - the Python and IPython shell,
# - the jupyter notebook,
# - web application servers,
#
# and four graphical user interface toolkits.
#
# ## Scripting Layer
#
#  - a collection of command style functions that make Matplotlib work like MATLAB.
#  - Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc
#
#  - you can run commands to check the running version
#  - or select a style like ggplot

# %%
# we are using the inline backend
# %matplotlib inline 

import matplotlib as mpl 
import matplotlib.pyplot as plt  #and then matplotlib's scripting interface as plt

print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0

print(plt.style.available)
mpl.style.use(['ggplot']) # optional: for ggplot-like style
# Out:
# Matplotlib version:  2.1.0
# ['classic', 'seaborn-darkgrid', 'grayscale', 'seaborn-whitegrid', 'seaborn-notebook', 'seaborn-bright', 'seaborn', 'seaborn-pastel', 'seaborn-deep', 'seaborn-paper', '_classic_test', 'ggplot', 'fivethirtyeight', 'dark_background', 'seaborn-poster', 'Solarize_Light2', 'fast', 'seaborn-white', 'seaborn-talk', 'seaborn-ticks', 'seaborn-dark-palette', 'seaborn-colorblind', 'seaborn-dark', 'bmh', 'seaborn-muted']

# %% [markdown]
# ## Plotting in Pandas
# Built-in pandas, just add **.plot()**
# - [Plotting with Series](http://pandas.pydata.org/pandas-docs/stable/api.html#plotting)<br>
# - [Plotting with Dataframes](http://pandas.pydata.org/pandas-docs/stable/api.html#api-dataframe-plotting)
#
# ### Line Plots
#
# - displaying info as a series of data points (markers),connected by staight line segments
# - best for a contcinuous dataset

# %%
df_can.set_index('Country', inplace = True)
haiti = df_can.loc['Haiti', years] # passing in years 1980 - 2013 to exclude the 'total' column
haiti.head()
# Out:
# 1980    1666
# 1981    3692
# 1982    3498
# 1983    2860
# 1984    1418
# Name: Haiti, dtype: object

# %%
haiti.plot()

# %% [markdown]
# ### Adding Title + Axis Labels using plt.title() and plt.x/ylabel()

# %%
haiti.index = haiti.index.map(int) # let's change the index values of Haiti to type integer for plotting
haiti.plot(kind='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show() # need this line to show the updates made to the figure

# %% [markdown]
# ### Adding Spike Annotation using plt.text()

# %%
haiti.plot(kind='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

# annotate the 2010 Earthquake. 
# syntax: plt.text(x, y, label)
plt.text(2005, 6500, '2010 Earthquake') # see note below

plt.show()

# %% [markdown]
# ### Let's try comparing several countries
#
# That doesn't look right...
#
# Remeber that pandas plots the indices on the x-axis and the columns as individual lines on the y-axis.
#
# Since df_CI is a dataframe with the country as the index and years as the columns,
# we must first transpose the dataframe using transpose() method to swap the row and columns!

# %%
#df_can = df_can.transpose()
#df.head()

# %%
compare = df_can.loc[{'Haiti','Bulgaria'}, years] # passing in years 1980 - 2013 to exclude the 'total' column
compare.head()

#WE NOW NEED TO TRANSPOSE THE DATA
comparet = compare.transpose()
comparet.head()

comparet.plot()

comparet.index = comparet.index.map(int) # let's change the index values of Haiti to type integer for plotting
comparet.plot(kind='line')

plt.title('Immigration from Haiti vs Bulgaria')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

plt.show() # need this line to show the updates made to the figure

# %% [markdown]
# ### Comparing the trend for the Top 5 Countries
#
# ### Step 1:
#
#
# Get the dataset. Recall that we created a Total column that calculates the cumulative immigration by country.
#
# We will sort on this column to get our top 5 countries using pandas sort_values() method.
#
# inplace = True paramemter saves the changes to the original df_can dataframe

# %%
df_can.sort_values(by='Total', ascending=False, axis=0, inplace=True)

# get the top 5 entries
df_top5 = df_can.head(5)

# transpose the dataframe
df_top5 = df_top5[years].transpose() 

print(df_top5)
# Out:
# Country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
# 1985      4211   1816                                               9564
# 1986      7150   1960                                               9470
# 1987     10189   2643                                              21337
# 1988     11522   2758                                              27359
# 1989     10343   4323                                              23795
# 1990     12041   8076                                              31668
# 1991     13734  14255                                              23380
# ...

# %% [markdown]
# ### Step 2:
#
# Plot the dataframe. To make the plot more readeable, we will change the size using the `figsize` parameter.

# %%
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='line', figsize=(14, 8)) # pass a tuple (x, y) size


plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# ### Other Plots
#
# There are many other plotting styles available other than the default Line plot, all of which can be accessed by passing kind keyword to plot(). The full list of available plots are as follows:
#
# - bar for vertical bar plots
# - barh for horizontal bar plots
# - hist for histogram
# - box for boxplot
# - kde or density for density plots
# - area for area plots
# - pie for pie plots
# - scatter for scatter plots
# - hexbin for hexbin plot

# %%
df_can.sort_values(by='Total', ascending=False, axis=0, inplace=True)

# get the top 5 entries
df_top = df_can.tail(10)

# transpose the dataframe
df_top = df_top[years].transpose() 

df_top.index = df_top.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top.plot(kind='line', figsize=(14, 8)) # pass a tuple (x, y) size


plt.title('Reverse Immigration Trend | Countries least likely to immigrate to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# # Basic & Specialized Viz Tools

# %% [markdown]
# ### Area plot/chart/graph
#
# - used for representing cumulated totals via numbers or percentages over time
# - based on the line plot

# %%
df_top5.plot(kind='area')

plt.title('Immigration Trend | Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# ### Histogram
#
# - representing frequency distribution of a numeric dataset
# - partitioning of data subsets into bins(counting how many data points are assigned to each bin)
#
#
# The comparison we used in the line graph is not suitable for meaningful viz with a histogram, so we should focus on a single year for example

# %%
df_top5.plot(kind='hist')

plt.title('Immigration Trend | Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
count, bin_edges = np.histogram(df_can['2013'])
df_can['2013'].plot(kind='hist', xticks = bin_edges)

plt.title('Histogram of Immigration for 2013')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')

plt.show()

# %% [markdown]
# ### Bar Charts
#
# - unlike the bins in the histogram,in bar charts the length of each bar is proportionate to the value it represents
# - preferrable for point-in-time data

# %%
years = list (map(str, range(1980,2014)))
df_bulgaria = df_can.loc['Bulgaria',years]

df_bulgaria.plot(kind='line')

plt.title('Bulgarian immigrants to Canada from 1980 to 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
print('Mean', df_bulgaria.mean())
print('Describe', df_bulgaria.describe())
print('Max', df_bulgaria.max())

df_romania = df_can.loc['Romania',years]
df_romania.plot(kind='line')

plt.title('Romanian immigrants to Canada from 1980 to 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()
# Out:
# Mean 685.588235294
# Describe count     34
# unique    31
# top       24
# freq       2
# Name: Bulgaria, dtype: int64
# Max 2022

# %% [markdown]
# ### Area Plots
# - type of cumulative plot
# - area plots are stacked by default. And to produce a stacked area plot, each column must be either all positive or all negative values (any NaN values will defaulted to 0).
# - to produce an unstacked plot, pass stacked=False

# %%
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='area', 
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='area', 
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
df_top5.plot(kind='area', 
             alpha=0.25, # 0-1, default value a= 0.5
             stacked=False,
             figsize=(20, 10),
            )

plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# ### How about doing the same chart for European Regions?

# %%
df_europe= df_can.loc[df_can['Continent'] == 'Europe']
df_europe.set_index('Region', inplace = True)
df_europe.head()
# Out:
#                        Type    Coverage  AREA Continent  REG  DEV  \
# Region
# Northern Europe  Immigrants  Foreigners   908    Europe  924  901
# Eastern Europe   Immigrants  Foreigners   908    Europe  923  901
# Western Europe   Immigrants  Foreigners   908    Europe  926  901
# Eastern Europe   Immigrants  Foreigners   908    Europe  923  901
# Southern Europe  Immigrants  Foreigners   908    Europe  925  901
#
#                            DevName   1980   1981   1982   ...    2005  2006  \
# Region                                                    ...
# Northern Europe  Developed regions  22045  24796  20620   ...    7258  7140
# Eastern Europe   Developed regions    863   2930   5881   ...    1405  1263
# Western Europe   Developed regions   1729   2027   2219   ...    4429  4002
# Eastern Europe   Developed regions    375    438    583   ...    5048  4468
# Southern Europe  Developed regions   4473   3486   2432   ...     338   424
#
# ...

# %%
# get the top 5 entries
df_topeu = df_europe.head(10)

# transpose the dataframe
df_topeu = df_topeu[years].transpose() 

df_topeu.index = df_topeu.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_topeu.plot(kind='line', figsize=(14, 8)) # pass a tuple (x, y) size


plt.title('Reverse Immigration Trend | Countries least likely to immigrate to Canada')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
df_reg = df_can.groupby('Region', axis = 0).sum()
df_reg.sort_values(by='Total', ascending=False, axis=0, inplace=True)
df_topreg= df_reg.head()
df_topreg = df_topreg[years].transpose()

df_topreg.plot(kind='area', 
             alpha=0.25, # 0-1, default value a= 0.5
             stacked=False,
             figsize=(20, 10),
            )

plt.title('Immigration Trend by Region')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# ### Pie Charts
#
# - Numeric proportions prepped using the groupby and sum functions
#
# - The general process of groupby involves the following steps:
#
# Split: Splitting the data into groups based on some criteria.
# Apply: Applying a function to each group independently:
# .sum()
# .count()
# .mean()
# .std()
# .aggregate()
# .apply()
# .etc..
# Combine: Combining the results into a data structure
#
# - Additional parameters
#
# -autopct - label the wedges with their numeric value. The label will be placed inside the wedge. If it is a format string, the label will be fmt%pct
# -startangle - rotates the start of the pie chart by angle degrees counterclockwise from the x-axis
# -shadow - Draws a shadow beneath the pie (to give a 3D feel).

# %%
df_continents = df_can.groupby('Continent', axis = 0).sum()
df_continents['Total'].plot(kind='pie')
plt.title ('Immmigration by Continent')

plt.show()

# %%
# autopct create %, start angle represent starting point
df_continents['Total'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %% [markdown]
# More modifications needed:
# - seperate legend - plt.legend()
# - push out the percentages to sit just outside - pctdistance parameter
# - custom set of colors - colors parameter
# - explode the pie chart - explode parameter

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

df_continents['Total'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                           )

# scale the title up by 12% to match pctdistance
plt.title('Immigration to Canada by Continent [1980 - 2013]', y=1.12) 

plt.axis('equal') 

# add legend
plt.legend(labels=df_continents.index, loc='upper left') 

plt.show()

# %% [markdown]
# ### Box Plots
#
# A box plot is a way of statistically representing the distribution of the data through five main dimensions:
#
# - Minimum: Smallest number in the dataset.
# - First quartile: Middle number between the minimum and the median.
# - Second quartile (Median): Middle number of the (sorted) dataset.
# - Third quartile: Middle number between median and maximum.
# - Maximum: Highest number in the dataset.
#
#
# One of the key benefits of box plots is comparing the distribution of multiple datasets

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Images/boxplot_complete.png" width=440, align="center">

# %% [markdown]
# We can also use boxplots to quickly check for:
# - normal distribution assumption (symmetry)
# - equal variences

# %%
df_bulgaria = df_can.loc[['Bulgaria'], years]

df_bulgaria = df_bulgaria.transpose()
df_bulgaria.plot(kind='box')

plt.title ('Box plot of Bulgarian Immigrants 1980 -2013')
plt.ylabel('Number of Immigrants')
plt.show()

# %% [markdown]
# Let's compare several countries: China and Bulgaria, for instance

# %%
df_CB = df_can.loc[['China','Bulgaria'], years].transpose()
df_CB.head()

df_CB.plot(kind='box')

plt.title ('Box plot of Bulgarian & Chinese Immigrants 1980 -2013')
plt.ylabel('Number of Immigrants')
plt.show()

# %% [markdown]
# If you prefer to create horizontal box plots, you can pass the vert parameter in the plot function and assign it to False.
#
# You can also specify a different color in case you are not a big fan of the default red colo

# %%
# horizontal box plots
df_CB.plot(kind='box', figsize=(10, 7), color='blue', vert=False)

plt.title('Box plots of Immigrants from China and Bulgaria (1980 - 2013)')
plt.xlabel('Number of Immigrants')

plt.show()

# %% [markdown]
# ## Drawing Subplots
#
# - Great for side-by-side comparison
# - We need to create a figure (overall canvas) and divide it into subplots
# - with subplots, we usually work with the artist layer instead of the scripting layer
#
# Typical syntax is : <br>
# ```python
#     fig = plt.figure() # create figure
#     ax = fig.add_subplot(nrows, ncols, plot_number) # create subplots
# ```
# - **`nrows` and `ncols`** are used to notionally split the figure into (`nrows` \* `ncols`) sub-axes,
# - **`plot_number`** is used to identify the particular subplot that this function is to create within the notional grid. `plot_number` starts at 1, increments across rows first and has a maximum of `nrows` * `ncols` as shown below.
#
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Images/Mod3Fig5Subplots_V2.png" width=500 align="center">

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

fig = plt.figure() # create figure

ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1, 2, 2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**

# Subplot 1: Box plot
df_CB.plot(kind='box', color='blue', vert=False, figsize=(20, 6), ax=ax0) # add to subplot 1
ax0.set_title('Box Plots of Immigrants from China and India (1980 - 2013)')
ax0.set_xlabel('Number of Immigrants')
ax0.set_ylabel('Countries')

# Subplot 2: Line plot
df_CB.plot(kind='line', figsize=(20, 6), ax=ax1) # add to subplot 2
ax1.set_title ('Line Plots of Immigrants from China and Bulgaria (1980 - 2013)')
ax1.set_ylabel('Number of Immigrants')
ax1.set_xlabel('Years')

plt.show()

# %% [markdown]
# ### **Subplot convention **
#
# When nrows, ncols, and plot_number are all less than 10, a convenience exists such that the a 3 digit number can be given instead, where the hundreds represent nrows, the tens represent ncols and the units represent plot_number.
#
#    subplot(211) == subplot(2, 1, 1)
#
# >> this represents subaxes in a figure which represents the top plot (i.e. the first) in a 2 rows x 1 column notional grid (no grid actually exists, but conceptually this is how the returned subplot has been positioned).

# %% [markdown]
# ### Top 15 Countries
# - new dataframe

# %%
df_top15 = df_can.sort_values(['Total'], ascending=False, axis=0).head(15)
df_top15
# Out:
#                                                           Type    Coverage  \
# Country
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
# United States of America                            Immigrants  Foreigners
# Iran (Islamic Republic of)                          Immigrants  Foreigners
# Sri Lanka                                           Immigrants  Foreigners
# Republic of Korea                                   Immigrants  Foreigners
# Poland                                              Immigrants  Foreigners
# Lebanon                                             Immigrants  Foreigners
# ...

# %% [markdown]
# - Listing series by decade

# %%
# create a list of all years in decades 80's, 90's, and 00's
years_80s = list(map(str, range(1980, 1990))) 
years_90s = list(map(str, range(1990, 2000))) 
years_00s = list(map(str, range(2000, 2010))) 

# slice the original dataframe df_can to create a series for each decade
df_80s = df_top15.loc[:, years_80s].sum(axis=1) 
df_90s = df_top15.loc[:, years_90s].sum(axis=1) 
df_00s = df_top15.loc[:, years_00s].sum(axis=1)

# merge the three series into a new data frame
new_df = pd.DataFrame({'1980s': df_80s, '1990s': df_90s, '2000s':df_00s}) 


# display dataframe
new_df.head()

#describe it
new_df.describe()

#boxplot it
new_df.plot(kind='box', figsize=(10, 6))

# %% [markdown]
# - removing the outliers identified in the boxplot

# %%
# let's check how many entries fall above the outlier threshold 
new_df[new_df['2000s']> 209611.5]
# Out:
#          1980s   1990s   2000s
# Country
# India    82154  180395  303591
# China    32003  161528  340385

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# The data in a scatter plot is considered to express a trend. With further analysis using tools like regression, we can mathematically calculate this relationship and use it to predict trends outside the dataset.
#
# - Step 1: Get the dataset. Since we are expecting to use the relationship betewen years and total population, we will convert years to **int type**.

# %%
# we can use the sum() method to get the total population per year
df_tot = pd.DataFrame(df_can[years].sum(axis=0))

# change the years to type int (useful for regression later on)
df_tot.index = map(int, df_tot.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_tot.reset_index(inplace = True)

# rename columns
df_tot.columns = ['year', 'total']

# view the final dataframe
df_tot.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %% [markdown]
# Step 2: Plot the data. In Matplotlib, we can create a scatter plot set by passing in kind='scatter' as plot argument. We will also need to pass in x and y keywords to specify the columns that go on the x- and the y-axis.

# %%
df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %% [markdown]
# - Step 3: Plotting  a linear line of best fit in order to predict the number of immigrants in 2015.
#
# Get the equation of line of best fit. We will use Numpy's polyfit() method by passing in the following:
#
# x: x-coordinates of the data
# y: y-coordinates of the data
# deg: Degree of fitting polynomial
# 1 = linear, 2 = quadratic, and so on

# %%
x = df_tot['year']      # year on x-axis
y = df_tot['total']     # total on y-axis
fit = np.polyfit(x, y, deg=1)

fit
# Out:
# array([  5.56709228e+03,  -1.09261952e+07])

# %%
df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

# plot line of best fit
plt.plot(x, fit[0] * x + fit[1], color='red') # recall that x is the Years
plt.annotate('y={0:.0f} x + {1:.0f}'.format(fit[0], fit[1]), xy=(2000, 150000))

plt.show()

# print out the line of best fit
'No. Immigrants = {0:.0f} * Year + {1:.0f}'.format(fit[0], fit[1])
# Out:
# 'No. Immigrants = 5567 * Year + -10926195'

# %% [markdown]
# ### LAB | Scatterplot for Scandinavian Countries

# %%
### DATAPREP
df_countries =  df_can.loc[{'Denmark','Norway','Sweden'}, years]

#we can use the sum() method to get the total population per year
df_countries = pd.DataFrame(df_can[years].sum(axis=0))

# change the years to type int (useful for regression later on)
df_countries.index = map(int, df_countries.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_countries.reset_index(inplace = True)

# rename columns
df_countries.columns = ['year', 'total']

# view the final dataframe
df_countries.head()

### DATAVIZ
df_countries.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Scandinavian Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

x = df_countries['year']      # year on x-axis
y = df_countries['total']     # total on y-axis
fit = np.polyfit(x, y, deg=1)

fit

df_countries.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

# plot line of best fit
plt.plot(x, fit[0] * x + fit[1], color='red') # recall that x is the Years
plt.annotate('y={0:.0f} x + {1:.0f}'.format(fit[0], fit[1]), xy=(2000, 150000))

plt.show()

# print out the line of best fit
'No. Immigrants = {0:.0f} * Year + {1:.0f}'.format(fit[0], fit[1])
# Out:
# 'No. Immigrants = 5567 * Year + -10926195'

# %% [markdown]
# ## Quick Data Clean-up Recap

# %%
# clean up the dataset to remove unnecessary columns (eg. REG) 
#df_can.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace=True)

# let's rename the columns so that they make sense
#df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent','RegName':'Region'}, inplace=True)

# for sake of consistency, let's also make all column labels of type string
#df_can.columns = list(map(str, df_can.columns))

# set the country name as index - useful for quickly looking up countries using .loc method
#df_can.set_index('Country', inplace=True)

# add total column
#df_can['Total'] = df_can.sum(axis=1)

# years that we will be using in this lesson - useful for plotting later on
#years = list(map(str, range(1980, 2014)))
#print('data dimensions:', df_can.shape)

#%matplotlib inline

#import matplotlib as mpl
#import matplotlib.pyplot as plt

#mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
#print('Matplotlib version: ', mpl.__version__) # >= 2.0.0

# %% [markdown]
# ### Data Normalization

# %%
 # normalize China data
norm_china = (df_can_t['China'] - df_can_t['China'].min()) / (df_can_t['China'].max() - df_can_t['China'].min())

# normalize India data
norm_india = (df_can_t['India'] - df_can_t['India'].min()) / (df_can_t['India'].max() - df_can_t['India'].min())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-9c575f962541> in <module>()
#       1 # normalize China data
# ----> 2 norm_china = (df_can_t['China'] - df_can_t['China'].min()) / (df_can_t['China'].max() - df_can_t['China'].min())
#       3
#       4 # normalize India data
#       5 norm_india = (df_can_t['India'] - df_can_t['India'].min()) / (df_can_t['India'].max() - df_can_t['India'].min())
#
# NameError: name 'df_can_t' is not defined

# %% [markdown]
# # _"To consult a statistician after an experiment is finished is often merely to ask him to conduct a post-mortem examination. He can perhaps say what the experiment died of"  R. A. Fischer_

# %% [markdown]
# ### Buble Plots
#
# A bubble plot is a variation of the scatter plot that displays three dimensions of data (x, y, z).
#
# The datapoints are replaced with bubbles, and the size of the bubble is determined by the third variable 'z', also known as the weight.
#
# In maplotlib, we can pass in an array or scalar to the keyword s to plot(), that contains the weight of each point.
#
# We will also **normalize** the data by using feature scaling

# %%
#Analyzing data for Argentinian immigration after the crisis in 1998-2002
df_can_t = df_can[years].transpose() # transposed dataframe

# cast the Years (the index) to type int
df_can_t.index = map(int, df_can_t.index)

# let's label the index. This will automatically be the column name when we reset the index
df_can_t.index.name = 'Year'

# reset index to bring the Year in as a column
df_can_t.reset_index(inplace=True)

# view the changes
df_can_t.head()

# normalize Brazil data
norm_brazil = (df_can_t['Brazil'] - df_can_t['Brazil'].min()) / (df_can_t['Brazil'].max() - df_can_t['Brazil'].min())

# normalize Argentina data
norm_argentina = (df_can_t['Argentina'] - df_can_t['Argentina'].min()) / (df_can_t['Argentina'].max() - df_can_t['Argentina'].min())

# %% [markdown]
# **Plotting**
#
# To plot two different scatter plots in one plot, we can include the axes one plot into the other by passing it via the ax parameter.
#
# We will also pass in the weights using the s parameter. Given that the normalized weights are between 0-1, they won't be visible on the plot.
#
# Therefore we will: multiply weights by 2000 to scale it up on the graph, and, add 10 to compensate for the min value (which has a 0 weight and therefore scale with x2000).

# %%
# Brazil
ax0 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Brazil',
                    figsize=(14, 8),
                    alpha=0.5,                  # transparency
                    color='green',
                    s=norm_brazil * 2000 + 10,  # pass in weights 
                    xlim=(1975, 2015)
                   )

# Argentina
ax1 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Argentina',
                    alpha=0.5,
                    color="blue",
                    s=norm_argentina * 2000 + 10,
                    ax = ax0
                   )

ax0.set_ylabel('Number of Immigrants')
ax0.set_title('Immigration from Brazil and Argentina from 1980 - 2013')
ax0.legend(['Brazil', 'Argentina'], loc='upper left', fontsize='x-large')

# %% [markdown]
# ### Waffle Charts
#
# - a way to visualize data in relation to a whole or to highlight progress to a threshold
# - not built-in in matplotlib: custom code required
#
# ### WordClouds
# - also need a special library outside of matplotlib
#
# ### Seaborn & Regression Plots
# - different library, but initially based on matplotlib
# - more efficient: requires less code than matplotlib: a single line of code can produce a scatterplot with multiple customization options

# %%
import seaborn as sns
ax = sns.regplot(x = 'year', y = 'total',
                 data = df_tot, 
                 color = 'purple',
                 marker = '*')

# %% [markdown]
# ## LAB | Waffle Charts, WordClouds, Regression Plots

# %% [markdown]
# _Toolkits: The course heavily relies on [*pandas*](http://pandas.pydata.org/) and [**Numpy**](http://www.numpy.org/) for data wrangling, analysis, and visualization. The primary plotting library we will explore in the course is [Matplotlib](http://matplotlib.org/)._
#
# _Dataset: Immigration to Canada from 1980 to 2013 - [International migration flows to and from selected countries - The 2015 revision](http://www.un.org/en/development/desa/population/migration/data/empirical2/migrationflows.shtml) from United Nation's website_
#
# ### Data Prep

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
from PIL import Image # converting images into arrays

#df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
 #                      sheet_name='Canada by Citizenship',
  #                     skiprows=range(20),
   #                    skipfooter=2)

# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches # needed for waffle Charts

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  2.1.0

# %% [markdown]
# ### Waffles

# %%
# let's create a new dataframe for these three countries 
df_dsn = df_can.loc[['Denmark', 'Norway', 'Sweden'], :]

# let's take a look at our dataframe
df_dsn

# STEP 1 = Compute the proportion of each category with respect to the total
total_values = sum(df_dsn['Total'])
category_proportions = [(float(value) / total_values) for value in df_dsn['Total']]

# print out proportions
for i, proportion in enumerate(category_proportions):
    print (df_dsn.index.values[i] + ': ' + str(proportion))
    
    
# STEP 2: Define the overall size of the waffle
width = 40 # width of chart
height = 10 # height of chart

total_num_tiles = width * height # total number of tiles

print ('Total number of tiles is ', total_num_tiles)

# STEP 3: Determine proportions
# compute the number of tiles for each catagory
tiles_per_category = [round(proportion * total_num_tiles) for proportion in category_proportions]

# print out number of tiles per category
for i, tiles in enumerate(tiles_per_category):
    print (df_dsn.index.values[i] + ': ' + str(tiles))
    
# STEP 4: Create a matrix and populate it
# initialize the waffle chart as an empty matrix
waffle_chart = np.zeros((height, width))

# define indices to loop through waffle chart
category_index = 0
tile_index = 0

# populate the waffle chart
for col in range(width):
    for row in range(height):
        tile_index += 1

        # if the number of tiles populated for the current category is equal to its corresponding allocated tiles...
        if tile_index > sum(tiles_per_category[0:category_index]):
            # ...proceed to the next category
            category_index += 1       
            
        # set the class value to an integer, which increases with class
        waffle_chart[row, col] = category_index
        
print ('Waffle chart populated!')

# STEP 5: Mat the matrix into a visual

# instantiate a new figure object
fig = plt.figure()

# use matshow to display the waffle chart
colormap = plt.cm.coolwarm
plt.matshow(waffle_chart, cmap=colormap)
plt.colorbar()

# STEP 6: Customize and pretty-up the chart
# instantiate a new figure object
fig = plt.figure()

# use matshow to display the waffle chart
colormap = plt.cm.coolwarm
plt.matshow(waffle_chart, cmap=colormap)
plt.colorbar()

# get the axis
ax = plt.gca()

# set minor ticks
ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
# add gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

plt.xticks([])
plt.yticks([])

# STEP 7: Add titles and legend
# create legend
legend_handles = []
for i, category in enumerate(df_dsn.index.values):
    label_str = category + ' (' + str(df_dsn['Total'][i]) + ')'
    color_val = colormap(float(values_cumsum[i])/total_values)
    legend_handles.append(mpatches.Patch(color=color_val, label=label_str))

# add legend to chart
plt.legend(handles=legend_handles,
           loc='lower center', 
           ncol=len(df_dsn.index.values),
           bbox_to_anchor=(0., -0.2, 0.95, .1)
          )
# Out:
# Denmark: 0.32691075740403097
# Norway: 0.24934706549056324
# Sweden: 0.4237421771054058
# Total number of tiles is  400
# Denmark: 131
# Norway: 100
# Sweden: 169
# Waffle chart populated!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-debf8a5b55cb> in <module>()
#      90 for i, category in enumerate(df_dsn.index.values):
#      91     label_str = category + ' (' + str(df_dsn['Total'][i]) + ')'
# ---> 92     color_val = colormap(float(values_cumsum[i])/total_values)
#      93     legend_handles.append(mpatches.Patch(color=color_val, label=label_str))
#      94
#
# NameError: name 'values_cumsum' is not defined

# %% [markdown]
# Let's combine all steps:
#  So let's combine all seven steps into one function called create_waffle_chart. This function would take the following parameters as input:
#
# - categories: Unique categories or classes in dataframe.
# - values: Values corresponding to categories or classes.
# - height: Defined height of waffle chart.
# - width: Defined width of waffle chart.
# - colormap: Colormap class
# - value_sign: In order to make our function more generalizable, we will add this parameter to address signs that could be associated with a value such as %, $, and so on. value_sign has a default value of empty string.

# %%
def create_waffle_chart(categories, values, height, width, colormap, value_sign=''):

    # compute the proportion of each category with respect to the total
    total_values = sum(values)
    category_proportions = [(float(value) / total_values) for value in values]

    # compute the total number of tiles
    total_num_tiles = width * height # total number of tiles
    print ('Total number of tiles is', total_num_tiles)
    
    # compute the number of tiles for each catagory
    tiles_per_category = [round(proportion * total_num_tiles) for proportion in category_proportions]

    # print out number of tiles per category
    for i, tiles in enumerate(tiles_per_category):
        print (df_dsn.index.values[i] + ': ' + str(tiles))
    
    # initialize the waffle chart as an empty matrix
    waffle_chart = np.zeros((height, width))

    # define indices to loop through waffle chart
    category_index = 0
    tile_index = 0

    # populate the waffle chart
    for col in range(width):
        for row in range(height):
            tile_index += 1

            # if the number of tiles populated for the current category 
            # is equal to its corresponding allocated tiles...
            if tile_index > sum(tiles_per_category[0:category_index]):
                # ...proceed to the next category
                category_index += 1       
            
            # set the class value to an integer, which increases with class
            waffle_chart[row, col] = category_index
    
    # instantiate a new figure object
    fig = plt.figure()

    # use matshow to display the waffle chart
    colormap = plt.cm.coolwarm
    plt.matshow(waffle_chart, cmap=colormap)
    plt.colorbar()

    # get the axis
    ax = plt.gca()

    # set minor ticks
    ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
    ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
    # add dridlines based on minor ticks
    ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

    plt.xticks([])
    plt.yticks([])

    # compute cumulative sum of individual categories to match color schemes between chart and legend
    values_cumsum = np.cumsum(values)
    total_values = values_cumsum[len(values_cumsum) - 1]

    # create legend
    legend_handles = []
    for i, category in enumerate(categories):
        if value_sign == '%':
            label_str = category + ' (' + str(values[i]) + value_sign + ')'
        else:
            label_str = category + ' (' + value_sign + str(values[i]) + ')'
            
        color_val = colormap(float(values_cumsum[i])/total_values)
        legend_handles.append(mpatches.Patch(color=color_val, label=label_str))

    # add legend to chart
    plt.legend(
        handles=legend_handles,
        loc='lower center', 
        ncol=len(categories),
        bbox_to_anchor=(0., -0.2, 0.95, .1)
    )

# %%
#WE CAN NOW DIRECTLY USE THE FUNCTION create_waffle chart

width = 40 # width of chart
height = 10 # height of chart

categories = df_dsn.index.values # categories
values = df_dsn['Total'] # correponding values of categories

colormap = plt.cm.coolwarm # color map class

create_waffle_chart(categories, values, height, width, colormap)
# Out:
# Total number of tiles is 400
# Denmark: 131
# Norway: 100
# Sweden: 169

# %% [markdown]
# ### Word Clouds

# %%
#!conda install -c conda-forge wordcloud==1.4.1 --yes
from wordcloud import WordCloud, STOPWORDS

# download file and save as alice_novel.txt
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/alice_novel.txt

# open the file and read it into a variable alice_novel
alice_novel = open('alice_novel.txt', 'r').read()
    
print ('File downloaded and saved!')

stopwords = set(STOPWORDS)

#instantiate a word cloud object
alice_wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# Generate the word cloud
alice_wc.generate(alice_novel)

# display the word cloud
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

#RESIZE

fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

# display the cloud
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

stopwords.add('said') # add the words said to stopwords

# re-generate the word cloud
alice_wc.generate(alice_novel)

# display the cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# download image
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Images/alice_mask.png
    
# save mask to alice_mask
alice_mask = np.array(Image.open('alice_mask.png'))
    
print('Image downloaded and saved!')

fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# instantiate a word cloud object
alice_wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask, stopwords=stopwords)

# generate the word cloud
alice_wc.generate(alice_novel)

# display the word cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-62-a934f233b8df> in <module>()
#       1 #!conda install -c conda-forge wordcloud==1.4.1 --yes
# ----> 2 from wordcloud import WordCloud, STOPWORDS
#       3
#       4 # download file and save as alice_novel.txt
#       5 get_ipython().system('wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/alice_novel.txt')
#
# ImportError: No module named 'wordcloud'

# %% [markdown]
# ### Canadian Immigration Wordcloud

# %%
total_immigration = df_can['Total'].sum()
total_immigration

max_words = 90
word_string = ''
for country in df_can.index.values:
    # check if country's name is a single-word name
    if len(country.split(' ')) == 1:
        repeat_num_times = int(df_can.loc[country, 'Total']/float(total_immigration)*max_words)
        word_string = word_string + ((country + ' ') * repeat_num_times)
                                     
# display the generated text
word_string

# create the word cloud
wordcloud = WordCloud(background_color='white').generate(word_string)

print('Word cloud created!')

# display the cloud
fig = plt.figure()
fig.set_figwidth(14)
fig.set_figheight(18)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-68a056e12275> in <module>()
#      14
#      15 # create the word cloud
# ---> 16 wordcloud = WordCloud(background_color='white').generate(word_string)
#      17
#      18 print('Word cloud created!')
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
# ### Regression Plots with Seaborn
#
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics. You can learn more about seaborn by following this link and more about seaborn regression plots by following this link.

# %%
# we can use the sum() method to get the total population per year
df_tot = pd.DataFrame(df_can[years].sum(axis=0))

# change the years to type float (useful for regression later on)
df_tot.index = map(float, df_tot.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_tot.reset_index(inplace=True)

# rename columns
df_tot.columns = ['year', 'total']

# view the final dataframe
df_tot.head()
# Out:
#      year   total
# 0  1980.0   99137
# 1  1981.0  110563
# 2  1982.0  104271
# 3  1983.0   75550
# 4  1984.0   73417

# %% [markdown]
# ## Folium
# - Data viz library for different types of Leaflet maps and geospatial data
# - enables data binding to a map for choropleth visualizations and passing visualizations as markers on themap
# - has a number of tilesets: built-in (OpenStreetMap, Mapbox, Stamen) and custom ones (Mapbox API keys)

# %%
#define the world map
# !pip install folium

import folium

world_map = folium.Map(
    location = [56.130, -106.35],
    zoom_start = 4,
    tiles= 'Stamen Toner')

world_map
# Out:
# ...
# tensorflow 1.3.0 requires tensorflow-tensorboard<0.2.0,>=0.1.0, which is not installed.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#define the world map
#!pip install folium

import folium

world_map = folium.Map(
    location = [56.130, -106.35],
    zoom_start = 4,
    tiles= 'Stamen Terrain')

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Adding Markers

# %%
## Adding marker to Ontario

#Create a feature group
ontario = folium.map.FeatureGroup()

#Style the feature group
ontario.add_child(folium.CircleMarker([51.25, -85.32],
                 radius = 5, color = 'red', 
                 fill_color = 'Red')
                 )

canada_map = folium.Map(
    location = [56.130, -106.35],
    zoom_start = 4,
    tiles= 'Stamen Toner')
canada_map.add_child(ontario)

#labeling the marker
folium.Marker([51.25, -85.32],
                 popup = 'Ontario').add_to(canada_map)

canada_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Choropleth Maps
# - thematic map with shaded areas or patterened in proportion to the measurement of the statistical variable on it (population density, per capita income, etc.)
# - requires a Geo JSON map
# - What is nice about Folium is that it was developed for the sole purpose of visualizing geospatial data. While other libraries are available to visualize geospatial data, such as plotly, they might have a cap on how many API calls you can make within a defined time frame. Folium, on the other hand, is completely free
#
# > Folium builds on the data wrangling strengths of the Python ecosystem and the mapping strengths of the Leaflet.js library. Manipulate your data in Python, then visualize it in on a Leaflet map via Folium.
#
# > INSTALL: !conda install -c conda-forge folium=0.5.0 --yes
# import folium

# %%
import folium

world_map = folium.Map(location=[56.130, -106.35], zoom_start=4)

# %% [markdown]
# ## Map Styles
#
# ### Stamen Toner
# - high contrast, black and white
# - great for data mashups, exploring meanders and coastal zones
#
# ### Stamen Terrain
# - feature hill shading & vegetation
# - labeling & linework generalization of dual-carriageway roads
#
# ### Mapbox Bright
# - borders are not visible with a low zoomlevel
# - all country names are displayed in English (rather than in the local language of each ccountry)

# %%
world_map = folium.Map(tiles='Stamen Toner')
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## LAB | Incidents Data
#
# > 1. **IncidntNum**: Incident Number
# > 2. **Category**: Category of crime or incident
# > 3. **Descript**: Description of the crime or incident
# > 4. **DayOfWeek**: The day of week on which the incident occurred
# > 5. **Date**: The Date on which the incident occurred
# > 6. **Time**: The time of day on which the incident occurred
# > 7. **PdDistrict**: The police department district
# > 8. **Resolution**: The resolution of the crime in terms whether the perpetrator was arrested or not
# > 9. **Address**: The closest address to where the incident took place
# > 10. **X**: The longitude value of the crime location
# > 11. **Y**: The latitude value of the crime location
# > 12. **Location**: A tuple of the latitude and the longitude values
# > 13. **PdId**: The police department ID

# %%
df_incidents = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Police_Department_Incidents_-_Previous_Year__2016_.csv')

print('Dataset downloaded and read into a pandas dataframe!')

df_incidents.shape

# get the first 100 crimes in the df_incidents dataframe
limit = 100
df_incidents = df_incidents.iloc[0:limit, :]

df_incidents.head()
# Out:
# Dataset downloaded and read into a pandas dataframe!
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
# ...

# %% [markdown]
# ### Mapping the incidents onto the SanFran map

# %%
# San Francisco latitude and longitude values
latitude = 37.77
longitude = -122.42

# create map and display it
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# display the map of San Francisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# loop through the 100 crimes and add each to the incidents feature group
for lat, lng, in zip(df_incidents.Y, df_incidents.X):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=5, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# add incidents to map
sanfran_map.add_child(incidents)

# add pop-up text to each marker on the map
latitudes = list(df_incidents.Y)
longitudes = list(df_incidents.X)
labels = list(df_incidents.Category)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(sanfran_map)    
    
# add incidents to map
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **But can we make the map less crowded?**
#
# - **Option 1** Removing the markers

# %%
# create map and display it
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# loop through the 100 crimes and add each to the map
for lat, lng, label in zip(df_incidents.Y, df_incidents.X, df_incidents.Category):
    folium.CircleMarker(
        [lat, lng],
        radius=5, # define how big you want the circle markers to be
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(sanfran_map)

# show map
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - **Option2**- grouping markers into clusters representing crime rates by neighbourhood (i.e. pockets within the city analyzed separately)
#
# > A special feature of this option is that it adapts clusters to zoom view

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
sanfran_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(sanfran_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(df_incidents.Y, df_incidents.X, df_incidents.Category):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

# display map
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Choropleth Maps | Canada

# %%
# download countries geojson file
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/world_countries.json -O world_countries.json
    
print('GeoJSON file downloaded!')

df_ca = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                     sheet_name='Canada by Citizenship',
                     skiprows=range(20),
                     skipfooter=2)

# clean up the dataset to remove unnecessary columns (eg. REG) 
df_ca.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

# let's rename the columns so that they make sense
df_ca.rename(columns={'OdName':'Country', 'AreaName':'Continent','RegName':'Region'}, inplace=True)

# for sake of consistency, let's also make all column labels of type string
df_ca.columns = list(map(str, df_ca.columns))

# add total column
df_ca['Total'] = df_ca.sum(axis=1)

# years that we will be using in this lesson - useful for plotting later on
years = list(map(str, range(1980, 2014)))
print ('data dimensions:', df_ca.shape)

print('Data downloaded and read into a dataframe!')
world_geo = r'world_countries.json' # geojson file

# create a plain world map
world_map = folium.Map(location=[0, 0], zoom_start=2, tiles='Mapbox Bright')

# generate choropleth map using the total immigration of each country to Canada from 1980 to 2013
world_map.choropleth(
    geo_data=world_geo,
    data=df_ca,
    columns=['Country', 'Total'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Immigration to Canada'
)

# display map
world_map
# Out:
# GeoJSON file downloaded!
# data dimensions: (195, 39)
# Data downloaded and read into a dataframe!
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/folium/folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
world_geo = r'world_countries.json'

# create a numpy array of length 6 and has linear spacing from the minium total immigration to the maximum total immigration
threshold_scale = np.linspace(df_ca['Total'].min(),
                              df_ca['Total'].max(),
                              6, dtype=int)
threshold_scale = threshold_scale.tolist() # change the numpy array to a list
threshold_scale[-1] = threshold_scale[-1] + 1 # make sure that the last value of the list is greater than the maximum immigration

# let Folium determine the scale.
world_map = folium.Map(location=[0, 0], zoom_start=2, tiles='Mapbox Bright')
world_map.choropleth(
    geo_data=world_geo,
    data=df_ca,
    columns=['Country', 'Total'],
    key_on='feature.properties.name',
    threshold_scale=threshold_scale,
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Immigration to Canada',
    reset=True
)
world_map
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/folium/folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#To remove the numbered columns and launch the dataframe with the first column as an index we should use the df index of the column (0)
df_survey = pd.read_csv('https://cocl.us/datascience_survey_data',index_col=0)
df_survey.head()

# %%
#CREATING A BAR CHART
#Step 1: Sorting in descending order of Very interested

df_survey.sort_values(by='Very interested', ascending=False, axis=0, inplace=True)

#Step 2: Converting numbers into percentages of total number

(100. * df_survey / df_survey.sum()).round(1).astype(str) + '%'

# %%
#No background colour
mpl.style.use('default')

df_survey.plot(kind='bar', figsize=(20, 8), width = 0.8, 
               color = ('#5cb85c','#5bc0de','#d9534f'),
               fontsize = 14)

#Removing the outlines
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
plt.title("Percentage of Respondents' Interest in Data Science Areas", fontsize = 16)

# %%
#df_crime = pd.read_csv('https://cocl.us/sanfran_crime_dataset')
#dfcrime = pd.DataFrame(df_crime['PdDistrict'].value_counts().astype(int))
#dfcrime.rename(columns={'PdDistrict':'District'}, inplace = True)
#dfcrime.reset_index()

#dfcrime.reset_index(inplace=True)
#dfcrime.rename(columns={'District':'Total'}, inplace = True)

#dfcrime.rename(columns={'index':'District'}, inplace = True)

dfcrime
# Out:
#      District  Total
# 0    SOUTHERN  28445
# 1    NORTHERN  20100
# 2     MISSION  19503
# 3     CENTRAL  17666
# 4     BAYVIEW  14303
# 5   INGLESIDE  11594
# 6     TARAVAL  11325
# 7  TENDERLOIN   9942
# 8    RICHMOND   8922
# 9        PARK   8699

# %%
# download countries geojson file
# !wget --quiet https://cocl.us/sanfran_geojson -O sanfran_geojson.json
 
#import folium 

print('GeoJSON file downloaded!')
#world_geo = r'world_countries.json' # geojson file
sanfran= r'sanfran_geojson.json'

# create a plain world map
latitude = 37.773972
longitude = -122.431297
sf_map = folium.Map(location=[latitude, longitude], zoom_start=12, tiles= 'OpenStreetMap')

sf_map
# Out:
# GeoJSON file downloaded!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# let Folium determine the scale.
folium.Choropleth(geo_data=sanfran,
    data=dfcrime,
    columns=['District','Total'],
    key_on='feature.properties.DISTRICT',  #the last section is crucial for coloring the different sections based on the right v
    threshold_scale=threshold_scale,
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Neighbourhood Crime Rate in San Francisco by KV').add_to(sf_map)

sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
